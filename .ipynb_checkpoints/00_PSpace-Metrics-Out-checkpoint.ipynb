# %%
import numpy as np
# from helpers import get_data
# from constants_v1 import *
# Plotting
import pandas as pd
from helpers_pd import *
pd.options.mode.chained_assignment = None  # default='warn'
import seaborn as sns
# plt.style.use('seaborn-white')
import matplotlib.pyplot as plt

# %%
gen = "Gen10"
df = get_data(gen=gen)
df["Gen"] = gen
len(df)
# Out:
# 550

# %%
# df1 = get_data(gen="Gen1")
# df3 = get_data(gen="Gen3")
# df4 = get_data(gen="Gen4")
# df6 = get_data(gen="Gen6")
# # df['K_d'] = df.loc[:, 'k_oc'] * df.loc[:,'f_oc']
# df1["Gen"] = "Gen1"
# df3["Gen"] = "Gen3"
# df4["Gen"] = "Gen4"
# df6["Gen"] = "Gen6"
# df = pd.concat([df1, df3, df4, df6])

# Index names
df['Name'] = df['Gen'] + "/" + df.index
df = df.set_index('Name')

# %%
# list(df)

# %%
# For later, 'KGE-d13C_out', 'NSE-d13C_out'
dfs = df[['Model', 'Gen',
          'z3_factor',
          'cZ0Z1',
          'cZ',
          'c_adr',
          'k_g',
          'gamma01',
          'gammaZ',
          'f_transp',
          'f_evap',
          'f_oc',
          'k_oc',
          'beta_runoff',
          'dt_50_aged',
          'dt_50_ab',
          'dt_50_ref',
          'epsilon_iso',
          'beta_moisture',
          'KGE-CONC-tra', 'KGE-d13C-tra',
          'KGE-CONC-blk', 'KGE-d13C-blk',
          'KGE-CONC-det', 'KGE-d13C-det',
          'KGE-Q_out', 'KGE-CONC_out', 'KGE-d13C_out',
          'MAE-CONC_out', 'MAE-d13C_out',
          'NSE-CONC_out', 'NSE-Q_out',
          'BIAS-CONC_out', 'BIAS-d13C_out',
          'BIAS-LDS_out',
          'BIAS-Q_out'
          ]]

# %%
dfs['KGE-SM'] = (dfs.loc[:, 'KGE-CONC_out'] + dfs.loc[:, 'KGE-CONC-blk'])/2.0  
dfs['KGE-d13C'] = (dfs.loc[:, 'KGE-d13C_out'] + dfs.loc[:, 'KGE-d13C-blk'])/2.0
# dfs['KGE-CONC_out'].max()
# dfs['KGE-CONC-blk'].max()
# dfs['KGE-SM'].max()
dfs['KGE-d13C_out'].max()
# dfs['NSE-Q_out' ].max()
# dfs['BIAS-CONC_out'].min()
# dfs['BIAS-LDS_out'].min()
# dfs['BIAS-d13C_out'].max()
# Out:
# 0.49204434571412836

# %%
# ff_out = dfs.loc[(dfs['KGE-Q_out'] > 0) &(dfs['KGE-CONC_out'] > 0) & (dfs['KGE-d13C_out'] > 0) ] # Outlet
ff_out = dfs.loc[(dfs['KGE-Q_out'] > 0) &(dfs['KGE-CONC-tra'] > .7) & (dfs['KGE-d13C-tra'] > .8) ] # Soils

print(len(ff_out))
# Out:
# 13

# %%
ff_out.head()
# Out:
#                        Model    Gen  z3_factor     cZ0Z1        cZ     c_adr  \
# Name
# Gen10/LHS_be1fix61/33/   fix  Gen10   0.960809  0.232486  0.245394  0.968425
# Gen10/LHS_be1fix61/4/    fix  Gen10   0.856624  0.634176  0.290341  0.980916
# Gen10/LHS_e1var61/29/    var  Gen10   0.951267  0.459165  0.458646  0.448633
# Gen10/LHS_s2fix61/16/    fix  Gen10   0.929607  0.155704  0.241373  0.209825
# Gen10/LHS_s2fix61/22/    fix  Gen10   0.850132  0.391154  0.412271  0.719236
#
#                                 k_g   gamma01    gammaZ  f_transp    ...     \
# Name                                                                 ...
# Gen10/LHS_be1fix61/33/  2361.294048  0.320897  0.352953  0.764590    ...
# Gen10/LHS_be1fix61/4/   2193.522351  0.189529  0.473935  0.902146    ...
# Gen10/LHS_e1var61/29/   3481.392331  0.552359  0.163868  0.686082    ...
# Gen10/LHS_s2fix61/16/   3603.668248  0.425625  0.600376  0.671647    ...
# Gen10/LHS_s2fix61/22/   1671.323301  0.257687  0.041618  0.935301    ...
#
#                         MAE-CONC_out  MAE-d13C_out  NSE-CONC_out  NSE-Q_out  \
# Name
# Gen10/LHS_be1fix61/33/      5.777943      1.379956    -10.953437   0.386860
# Gen10/LHS_be1fix61/4/       1.889479      2.173016     -0.014071   0.152297
# Gen10/LHS_e1var61/29/       2.598296      1.007267     -0.742598   0.392891
# Gen10/LHS_s2fix61/16/       1.855616      0.999958     -0.055963   0.342876
# Gen10/LHS_s2fix61/22/       2.405905      1.088366     -0.394873   0.286097
#
#                         BIAS-CONC_out  BIAS-d13C_out  BIAS-LDS_out  \
# Name
# Gen10/LHS_be1fix61/33/     174.352645      -1.340731    897.281891
# Gen10/LHS_be1fix61/4/      -68.527309      -3.844767     41.687024
# Gen10/LHS_e1var61/29/        1.247584      -1.932505    265.916497
# Gen10/LHS_s2fix61/16/      -75.296013       0.656757    -25.870145
# Gen10/LHS_s2fix61/22/      -18.723837      -0.513771    244.985166
#
#                         BIAS-Q_out    KGE-SM  KGE-d13C
# Name
# Gen10/LHS_be1fix61/33/    0.701653 -0.712309  0.017045
# Gen10/LHS_be1fix61/4/    57.218257  0.336261 -0.533995
# Gen10/LHS_e1var61/29/    19.487083  0.477869  0.420768
# Gen10/LHS_s2fix61/16/   -26.779822  0.286597  0.336173
# Gen10/LHS_s2fix61/22/    50.606939  0.565718  0.405156
#
# [5 rows x 38 columns]

# %%
ff_out['IsoCstr'] = ff_out.apply(IsoKGEout, args=(0.2,), axis=1)

# %%
dm_simp = pd.melt(ff_out, 
                 id_vars=['KGE-SM', 'KGE-d13C', 'KGE-CONC-tra', 'KGE-d13C-tra', 'KGE-d13C-det',
                          'BIAS-Q_out', 'BIAS-d13C_out','BIAS-CONC_out', 'BIAS-LDS_out',
                          'NSE-Q_out',
                          'MAE-d13C_out', 'MAE-CONC_out', 
                          'KGE-d13C_out','KGE-CONC_out', 'KGE-Q_out',
                          'Gen',  'Model', 'IsoCstr', 'NSE-CONC_out', ],
             value_vars=['z3_factor',
                         'cZ0Z1',
                         'cZ',
                         'c_adr',
                         'k_g',
                         'gamma01',
                         'gammaZ',
                         'f_transp',
                         'f_evap',
                         'f_oc',
                         'k_oc',
                         'beta_runoff',
                         'dt_50_aged',
                         'dt_50_ab',
                         'dt_50_ref',
                         'epsilon_iso',
                         'beta_moisture'])

# %%
dm_simp.head()
# Out:
#      KGE-SM  KGE-d13C  KGE-CONC-tra  KGE-d13C-tra  KGE-d13C-det  BIAS-Q_out  \
# 0 -0.712309  0.017045      0.802267      0.846935      0.677723    0.701653
# 1  0.336261 -0.533995      0.725788      0.835632      0.592502   57.218257
# 2  0.477869  0.420768      0.700901      0.872369      0.614550   19.487083
# 3  0.286597  0.336173      0.730533      0.838337      0.634886  -26.779822
# 4  0.565718  0.405156      0.787523      0.810352      0.493902   50.606939
#
#    BIAS-d13C_out  BIAS-CONC_out  BIAS-LDS_out  NSE-Q_out    ...     \
# 0      -1.340731     174.352645    897.281891   0.386860    ...
# 1      -3.844767     -68.527309     41.687024   0.152297    ...
# 2      -1.932505       1.247584    265.916497   0.392891    ...
# 3       0.656757     -75.296013    -25.870145   0.342876    ...
# 4      -0.513771     -18.723837    244.985166   0.286097    ...
#
#    MAE-CONC_out  KGE-d13C_out  KGE-CONC_out  KGE-Q_out    Gen Model  \
# 0      5.777943     -0.558247     -2.152088   0.705031  Gen10   fix
# 1      1.889479     -1.655647     -0.105487   0.340407  Gen10   fix
# 2      2.598296      0.004736      0.300009   0.643752  Gen10   var
# 3      1.855616      0.034461     -0.203768   0.578551  Gen10   fix
# 4      2.405905      0.050790      0.333123   0.417249  Gen10   fix
#
#           IsoCstr NSE-CONC_out   variable     value
# 0  KGE-d13C < 0.2   -10.953437  z3_factor  0.960809
# 1  KGE-d13C < 0.2    -0.014071  z3_factor  0.856624
# 2  KGE-d13C < 0.2    -0.742598  z3_factor  0.951267
# 3  KGE-d13C < 0.2    -0.055963  z3_factor  0.929607
# 4  KGE-d13C < 0.2    -0.394873  z3_factor  0.850132
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Overall

# %%
# g = sns.FacetGrid(dm_simp, col="variable", hue="Gen", col_wrap=4, sharex=False)
g = sns.FacetGrid(dm_simp, col="variable", hue="Model", col_wrap=4, sharex=False)
g = g.map(plt.scatter, "value", 'KGE-d13C-tra', edgecolor="w").add_legend()

# %%
g = sns.FacetGrid(dm_simp, col="variable", hue="Model", col_wrap=4, sharex=False)
g = g.map(plt.scatter, "value", "KGE-d13C", edgecolor="w").add_legend()

# %% [markdown]
# ## Outlet, fix vs. var

# %%
g = sns.FacetGrid(dm_simp, col="variable", hue="Model", col_wrap=4, sharex=False)
g = g.map(plt.scatter, "value", "KGE-d13C_out", edgecolor="w").add_legend()

# %%
g = sns.FacetGrid(dm_simp, col="variable", hue="Model", col_wrap=4, sharex=False)
g = g.map(plt.scatter, "value", "KGE-CONC_out", edgecolor="w").add_legend()

# %%
g = sns.FacetGrid(dm_simp, col="variable", hue="Model", col_wrap=4, sharex=False)
g = g.map(plt.scatter, "value", "BIAS-d13C_out", edgecolor="w").add_legend()

# %%
g = sns.FacetGrid(dm_simp, col="variable", hue="Model", col_wrap=4, sharex=False)
g = g.map(plt.scatter, "value", "MAE-d13C_out", edgecolor="w").add_legend()

# %%
g = sns.FacetGrid(dm_simp, col="variable", hue="Gen", col_wrap=4, sharex=False)
g = g.map(plt.scatter, "value", "BIAS-CONC_out", edgecolor="w").add_legend()

# %%
g = sns.FacetGrid(dm_simp, col="variable", hue="Model", col_wrap=4, sharex=False)
g = g.map(plt.scatter, "value", "BIAS-Q_out", edgecolor="w").add_legend()

# %%
g = sns.FacetGrid(dm_simp, col="variable", hue="Model", col_wrap=4, sharex=False)
g = g.map(plt.scatter, "value", "KGE-Q_out", edgecolor="w").add_legend()

# %%
g = sns.FacetGrid(dm_simp, col="variable", hue="Model", col_wrap=4, sharex=False)
g = g.map(plt.scatter, "value", "NSE-Q_out", edgecolor="w").add_legend()

# %%
np.log(2)/2000.
# Out:
# 0.00034657359027997266

# %%
np.log(2)/100.
# Out:
# 0.006931471805599453

# %% [markdown]
# ## Fit d13C, 1:1

# %%
path = '../phd-model-process/'
obs_d13c = pd.read_table(path + 'observations/d13c_out_cal.tss')
obs_conc = pd.read_table(path + 'observations/conc_out_cal.tss')
obs_d13c.head()
# Out:
#    Jdays       d13C
# 0    183 -31.518176
# 1    189 -31.185525
# 2    190 -31.280000
# 3    198 -30.966667
# 4    199 -30.916045

# %%
# ff_out = dfs.loc[(dfs['KGE-Q_out'] > 0) &(dfs['KGE-CONC_out'] > 0) & (dfs['KGE-d13C_out'] > -1.33) ] # Gen 8
ff_out = dfs.loc[(dfs['KGE-Q_out'] > .5) &(dfs['KGE-CONC_out'] > .2) & (dfs['KGE-d13C_out'] > .2) ] # Gen 7
var_list = ff_out.index[(ff_out['Model'] == 'var')].tolist() #[0]
# var_list = ff_out.index.tolist() #[0]
len(var_list)
# Out:
# 7

# %%
var_list
ff_out.loc[(ff_out['Model'] == 'var')]['dt_50_ref']
# Out:
# Name
# Gen10/LHS_e1var62/28/     39.238281
# Gen10/LHS_s2var61/10/     64.837776
# Gen10/LHS_sc1var62/20/    52.204928
# Gen10/LHS_sc1var63/10/    49.940715
# Gen10/LHS_sc1var63/11/    21.155814
# Gen10/LHS_sc1var64/13/    51.878552
# Gen10/LHS_sc1var64/21/    61.752053
# Name: dt_50_ref, dtype: float64

# %%
d13c = get_sets(var_list, path, 'resM_outISO_d13C.tss', "out-d13C")
# d13c = get_sets(var_list, path, 'resM_outISO_ROFF_d13C.tss', "out-d13C")
# d13c = get_sets(var_list, path, 'resM_outISO_LF_d13C.tss', "out-d13C")
# d13c = get_sets(var_list, path, 'resM_outISO_ADR_d13C.tss', "out-d13C")

# %%
d13c_merged = pd.merge(d13c, obs_d13c, how='inner', on='Jdays')
d13c_merged.head(2)
# Out:
#    Jdays  out-d13C_s2var56/28/  out-d13C_sc1var55/18/       d13C
# 0    183              -31.8118               -31.4885 -31.518176
# 1    189              -31.6338               -31.1800 -31.185525

# %%
203-171
# 198-171
# Out:
# 32

# %%
time = np.array(d13c_merged['Jdays']-171)
obs = np.array(d13c_merged['d13C'])

x = np.arange(d13c_merged['d13C'].min()-1, 
              d13c_merged['d13C'].max()+5, 0.2) 
y = x
sims = []

for i in range(1, len(np.array(d13c_merged.iloc[0, 1:]))):
    arr = np.array(d13c_merged.iloc[:, i])
    arr[arr > 0.99] = np.nan
    sims.append(arr)

# %%
palette = ["#F44336", '#673AB7', '#3F51B5', '#009688', '#FF9800', '#4CAF50', '#03A9F4']
# red, purple, indigo, teal-green, orange, green, light-blue
# https://matplotlib.org/users/dflt_style_changes.html

fig = plt.figure()

ax1 = plt.subplot(111) 

ax1.plot(x, y, label='y=x', c= "black")
for i in range(len(sims)):
    ax1.scatter(obs, sims[i], c= palette[i], marker='.', s=time,
                label="Sim "+ str(i), alpha=.9)
ax1.legend() 
ax1.set_xlabel("Obs.")
ax1.set_ylabel("Sim.")
# Out:
# Text(0,0.5,'Sim.')

# %%
time
# Out:
# array([12, 18, 19, 27, 28, 31, 32, 39, 40, 41, 42, 43, 44, 67, 68, 69, 70,
#        71, 74, 75, 76, 81, 82, 83, 84, 85, 86, 95, 96, 97])

# %%
fig = plt.figure()

ax1 = plt.subplot(111) 

for i in range(len(sims)):
    ax1.scatter(time, sims[i], c= palette[i], marker='.', s=time,
                label="Sim "+ str(i), alpha=.9)
ax1.scatter(time, obs, c= 'black', marker='.', s=time,
                label="Obs")

# %%
conc = get_sets(var_list, path, 'resM_oCONC_ugL.tss', "out-d13C")
conc_merged = pd.merge(conc, obs_conc, how='inner', on='Jdays')
conc_merged.head()
# Out:
#    Jdays  out-d13C_s2var56/28/  out-d13C_sc1var55/18/      ug.L
# 0    178              0.038285               0.004055  0.245659
# 1    179              0.049776               0.000455  0.245659
# 2    180              0.038392               0.000141  0.245659
# 3    183             17.246700              14.454200  6.729720
# 4    189              7.788880               6.906570  6.454391

# %%
time = np.array(conc_merged['Jdays']-171)
obs = np.array(conc_merged['ug.L'])

x = np.arange(conc_merged['ug.L'].min()-1, 
              conc_merged['ug.L'].max()+5, 0.2) 
y = x
sims = []

for i in range(1, len(np.array(conc_merged.iloc[0, 1:]))):
    arr = np.array(conc_merged.iloc[:, i])
#     arr[arr > 0.99] = np.nan
    sims.append(arr)

fig = plt.figure()

ax1 = plt.subplot(111) 

ax1.plot(x, y, label='y=x', c= "black")
for i in range(len(sims)):
    ax1.scatter(obs, sims[i], c= palette[i], marker='.', s=time,
                label="Sim "+ str(i), alpha=.9)
ax1.legend() 
ax1.set_xlabel("Obs.")
ax1.set_ylabel("Sim.")
# Out:
# Text(0,0.5,'Sim.')

# %%
fig = plt.figure()

ax1 = plt.subplot(111) 

for i in range(len(sims)):
    ax1.scatter(time, sims[i], c= palette[i], marker='.', s=time,
                label="Sim "+ str(i), alpha=.9)
ax1.scatter(time, obs, c= 'black', marker='.', s=time,
                label="Obs")

# %%
np.log(2)/3000.
# Out:
# 0.00023104906018664843

# %%
np.log(2)/30.
# Out:
# 0.023104906018664842
