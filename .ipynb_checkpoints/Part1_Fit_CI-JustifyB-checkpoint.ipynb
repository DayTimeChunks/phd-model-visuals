# %% [markdown]
# # Objective
#
# Check whether calibration can be done with total catchment mass per transect area.
# Results show this would not be a good approach to compare sampled values.

# %%
path = '../phd-model-process/'

import pandas as pd
pd.options.mode.chained_assignment = None  # default='warn'
import numpy as np
import scipy as sp
import scipy.stats as st

from helpers_pd import *

# Plotting
import seaborn as sns
sns.set()
# import seaborn as sns; sns.set(style="ticks", color_codes=True)
# sns.set(style="darkgrid")
import matplotlib.pyplot as plt
# plt.style.use('seaborn-white')

# %%
palette = ["#F44336", '#673AB7', '#3F51B5', '#009688', '#FF9800', '#4CAF50', '#03A9F4']
# red, purple, indigo, teal-green, orange, green, light-blue

# %% [markdown]
# # Extracting observed Conc.

# %% [markdown]
# ## Define transect

# %%
comp = pd.read_table(path + 'observations/conc_comp_cal.tss')
comp.head()
# Out:
#    Jdays Transect  IDcal      ug.g   ug.g.SD
# 0    188        N  N-188  1.854481  0.176483
# 1    188        S  S-188  7.623602  0.110718
# 2    188        V  V-188  1.707151  0.038673
# 3    197        N  N-197  5.628515  0.058313
# 4    197        S  S-197  3.686628  0.310806

# %%
det = pd.read_table(path + 'observations/conc_det_cal.tss')
det.head()
# Out:
#    Jdays Transect   IDcal      ug.g
# 0    181        N  N1-181  0.071209
# 1    181        N  N2-181  4.710027
# 2    181        N  N3-181  1.486026
# 3    181        N  N4-181  0.023645
# 4    181        N  N5-181  0.158614

# %%
obs = pd.concat([comp, det])
obs.head()
# Out:
#    IDcal  Jdays Transect      ug.g   ug.g.SD
# 0  N-188    188        N  1.854481  0.176483
# 1  S-188    188        S  7.623602  0.110718
# 2  V-188    188        V  1.707151  0.038673
# 3  N-197    197        N  5.628515  0.058313
# 4  S-197    197        S  3.686628  0.310806

# %% [markdown]
# # Selecting indexes

# %%
df = get_data()

# %%
# 'LHS_s2fix7/10/' in list(df.index)
# list(df)

# %%
df['k_d'] = df.loc[:, 'k_oc'] * df.loc[:,'f_oc']
# Combined outlet and transects KGE Concentrations and d13C
df['KGE-SM'] = (df.loc[:, 'KGE-CONC_out'] + df.loc[:, 'KGE-CONC-tra'])/2.0  
df['KGE-d13C'] = (df.loc[:, 'KGE-d13C_out'] + df.loc[:, 'KGE-d13C-tra'])/2.0
df['Constraint'] = df.apply(WithIsoKGE, args=(0.6,), axis=1)

# %%
print("Maximum Q")
print(df['KGE-Q_out'].max(), df['NSE-Q_out'].max()) 
print("Maximum Conc.")
print(df['KGE-CONC-tra'].max(), df['KGE-CONC_out'].max(), df['KGE-SM'].max()) 
print("Maximum d13C")
print(df['KGE-d13C-tra'].max(), df['KGE-d13C_out'].max(), df['KGE-d13C'].max())
# Out:
# Maximum Q
# (0.7856671938254698, 0.5624784847441313)
# Maximum Conc.
# (0.712486405538371, 0.36008130938978367, 0.4911975969993577)
# Maximum d13C
# (0.9031088875320538, 0.70432567774303, 0.7895610427604134)

# %%
dfs = df[['Model',
#           'dt_50_ref',
#           'k_d',
#           'epsilon_iso',
          'KGE-SM', 'KGE-d13C', 'Constraint'
          ]]

# %%
# Filter
ff = dfs.loc[(dfs['KGE-SM'] > 0.21)] # Try 25 with more data points
ff_c = ff.loc[(ff['KGE-d13C'] > 0.6)]
print(len(dfs), len(ff), len(ff_c))
ff.tail()
# Out:
# (6830, 376, 16)
#                  Model    KGE-SM  KGE-d13C Constraint
# LHS_sc1fix6/60/    fix  0.250903 -0.866467         NC
# LHS_sc1var1/319/   var  0.244648 -1.176122         NC
# LHS_sc1var1/64/    var  0.425198  0.222959         NC
# LHS_sc1var3/83/    var  0.325851 -1.289182         NC
# LHS_sc1var3/96/    var  0.237736  0.227875         NC

# %%
nc = ff.index[(ff['Constraint'] == 'NC')].tolist() #[0]
wc = ff.index[(ff['Constraint'] == 'WC')  ].tolist() # & (ff['Model']=='var')
print(len(nc), len(wc))

# nc = nc[0:len(wc)]

print(len(nc), len(wc))
# Out:
# (360, 16)
# (360, 16)

# %%
error = ['LHS_be1var1/115/', 'LHS_e1fix3/82/']
wc.pop(wc.index('LHS_be1var1/115/'))
wc.pop(wc.index('LHS_e1fix3/82/'))
# Out:
# 'LHS_e1fix3/82/'

# %%
list(wc)
# Out:
# ['LHS_be1fix7/78/',
#  'LHS_bo1fix6/191/',
#  'LHS_bo1fix6/258/',
#  'LHS_e1fix6/199/',
#  'LHS_gu1fix7/16/',
#  'LHS_gu1var6/23/',
#  'LHS_m1var7/70/',
#  'LHS_p1fix4/8/',
#  'LHS_p1var6/103/',
#  'LHS_p1var6/108/',
#  'LHS_p1var6/179/',
#  'LHS_s2fix7/6/',
#  'LHS_s2var5/63/',
#  'LHS_sc1fix6/21/']

# %% [markdown]
# # Bulk density
#
# All data frames have this time series, and does not change

# %%
pb = pd.read_table(path + 'observations/p_bAve.tss')
pb.head()
# Out:
#    Jdays  pbAve
# 0      1   1.36
# 1      2   1.36
# 2      3   1.36
# 3      4   1.36
# 4      5   1.36

# %% [markdown]
# # Extracting time series

# %%
def get_sets(name_list, filename, vname):
    sets = []
    for i in range(len(name_list)):
        # Define variable name
        series_name = vname + name_list[i][3:] # Variable + set's name
        # Get sim TSS
        sim = pd.read_table(path + name_list[i] + filename, 
                       skiprows=4, delim_whitespace=True,
                                    names=['Jdays', series_name],
                                    header=None
                      )
        sim = sim[['Jdays', series_name]]
        sets.append(sim)
    df = reduce(lambda left, right: pd.merge(left,right,on='Jdays'), sets)
    return df

# %%
def get_mass_to_conc(name_list, filename, vname, area):
    sets = []
    for i in range(len(name_list)):
        # Define variable name
        series_name = vname + name_list[i][3:] # Variable + set's name
        # Get sim TSS
        
        sim = pd.read_table(path + name_list[i] + filename, 
                       skiprows=4, delim_whitespace=True,
                                    names=['Jdays', 'sim'],
                                    header=None
                      )
    
#         sim[series_name] = sim['sim']
        sim[series_name] = ((sim['sim']/(area*10))/pb['pbAve'])*10**6/10**3 # ug/g soil
        sim = sim[['Jdays', series_name]]
        sets.append(sim)
    df = reduce(lambda left, right: pd.merge(left,right,on='Jdays'), sets)
    return df

# %% [markdown]
# # Confidence interval calc.

# %%
def concat(row, plot):
    return plot.capitalize() + '-' + str(int(row['Jdays']))

# %%
def get_stats_df(df, loc, level, cst):
    n = len(np.array(df.iloc[0,1:]))
    df['mean'] = df.iloc[:,1:].mean(axis=1)
    df['min'] = df.iloc[:,1:].min(axis=1)
    df['max'] = df.iloc[:,1:].max(axis=1)
    df['sem'] = df.iloc[:,1:].sem(axis=1)
    df['high'] = df.apply(get_ci, args=(n, 0.95, True), axis=1)
    df['low'] = df.apply(get_ci, args=(n, 0.95, False), axis=1)
    df['low'] = df.apply(check_negative, axis=1)
    df['Trans'] = loc
    df['Area'] = loc[0]
    df['Level'] = level  # Composite or Detailed, 
    df['IDcal'] = df.apply (lambda row: concat(row, loc), axis=1)
    df['Type'] = df.apply(lambda row: ModelType(row, cst),axis=1)
    return df[['Jdays', 'mean', 'high', 'low', 'max', 'min', 'Trans', 'Area', 'Level', 'IDcal', 'Type']]

# %%
# smp = comp = ['nor', 'val', 'sou']
# areas = [132876.0, 43716.0, 126940.0]
# label = ['No d13C', 'With d13C']
# wc_stat = []
# level = "Composite"
# for i in range(len(smp)):
#         if level == "Composite":
#             filename = "resM_lhr_" + smp[i] + '_z0.tss'
#             sets = get_mass_to_conc(wc, filename, smp[i], areas[i]) # Returns sets merged
#             end = 1
#         else: 
#             filename = "resM_" + smp[i] + 'CONC_real.tss'
#             sets =  get_sets(wc, filename, smp[i])
#             end = None
            
#         df = get_stats_df(sets, smp[i][0:end].capitalize(), level, label[1]) # Analyzed sets, WC!

#         wc_stat.append(df) # nc_stat

# %%
# wc_stat[0]
# Out:
#      Jdays      mean      high       low       max       min Trans Area  \
# 0      166  0.167112  0.167172  0.167052  0.167253  0.166910     N    N
# 1      167  0.166433  0.166552  0.166313  0.166708  0.166031     N    N
# 2      168  0.165759  0.165937  0.165581  0.166169  0.165159     N    N
# 3      169  0.165091  0.165327  0.164855  0.165634  0.164295     N    N
# 4      170  0.164429  0.164722  0.164137  0.165102  0.163442     N    N
# 5      171  3.303531  3.317841  3.289222  3.353403  3.270968     N    N
# 6      172  3.192338  3.218917  3.165758  3.285698  3.134894     N    N
# 7      173  3.086894  3.124569  3.049220  3.219421  3.005688     N    N
# 8      174  2.987667  3.035382  2.939952  3.154539  2.879205     N    N
# 9      175  2.891369  2.948621  2.834117  3.091023  2.758294     N    N
# 10     176  2.798333  2.864509  2.732157  3.028825  2.642717     N    N
# 11     177  6.048106  6.134562  5.961650  6.343209  5.837984     N    N
# 12     178  5.819102  5.900459  5.737745  6.102715  5.585426     N    N
# 13     179  5.628579  5.725866  5.531291  5.964927  5.344772     N    N
# 14     180  6.006532  6.131588  5.881476  6.437165  5.641626     N    N
# 15     181  5.801679  5.936025  5.667332  6.256435  5.398883     N    N
# 16     182  5.616091  5.764214  5.467969  6.112816  5.167103     N    N
# 17     183  5.361178  5.509029  5.213327  5.805778  4.942689     N    N
# 18     184  5.144202  5.315678  4.972726  5.649371  4.591790     N    N
# 19     185  4.967626  5.149609  4.785643  5.497854  4.377179     N    N
# 20     186  4.818575  5.002066  4.635085  5.350713  4.271445     N    N
# 21     187  4.668908  4.855173  4.482643  5.203380  4.146394     N    N
# 22     188  4.517382  4.710804  4.323960  5.064189  3.969824     N    N
# 23     189  4.346733  4.562975  4.130492  4.927725  3.638950     N    N
# 24     190  4.205788  4.421508  3.990068  4.796194  3.535181     N    N
# 25     191  4.070328  4.285075  3.855581  4.668279  3.440639     N    N
# 26     192  3.938260  4.152118  3.724402  4.540229  3.335081     N    N
# 27     193  3.812801  4.028384  3.597218  4.412232  3.189333     N    N
# 28     194  3.698374  3.915978  3.480771  4.294885  3.055164     N    N
# 29     195  3.588256  3.807852  3.368659  4.180757  2.926915     N    N
# ..     ...       ...       ...       ...       ...       ...   ...  ...
# 94   Composite  N-260  With d13C
# 95   Composite  N-261  With d13C
# 96   Composite  N-262  With d13C
# 97   Composite  N-263  With d13C
# 98   Composite  N-264  With d13C
# 99   Composite  N-265  With d13C
# 100  Composite  N-266  With d13C
# 101  Composite  N-267  With d13C
# 102  Composite  N-268  With d13C
# 103  Composite  N-269  With d13C
# 104  Composite  N-270  With d13C
# 105  Composite  N-271  With d13C
# 106  Composite  N-272  With d13C
# 107  Composite  N-273  With d13C
# 108  Composite  N-274  With d13C
# 109  Composite  N-275  With d13C
# 110  Composite  N-276  With d13C
# 111  Composite  N-277  With d13C
# 112  Composite  N-278  With d13C
# 113  Composite  N-279  With d13C
# 114  Composite  N-280  With d13C
# 115  Composite  N-281  With d13C
# 116  Composite  N-282  With d13C
# 117  Composite  N-283  With d13C
# 118  Composite  N-284  With d13C
# 119  Composite  N-285  With d13C
# 120  Composite  N-286  With d13C
#
# [121 rows x 11 columns]

# %%
comp = ['nor', 'val', 'sou']
areas = [132876.0, 43716.0, 126940.0]

det = ['n1', 'n2', 'n4', 'n7', 'n8',
       'v4', 'v7', 'v8', 'v9', 'v10',
       's11', 's12', 's13']

levels = ["Composite", "Detailed"]
label = ['No d13C', 'With d13C']

# constrained sets
wc_stat = []
for level in levels:
    
    if level == "Composite":
        smp = comp
    else:
        smp = det
        
    for i in range(len(smp)):
        if level == "Composite":
            filename = "resM_lhr_" + smp[i] + '_z0.tss'
            sets = get_mass_to_conc(wc, filename, smp[i], areas[i]) # Returns sets merged
            end = 1
        else: 
            filename = "resM_" + smp[i] + 'CONC_real.tss'
            sets =  get_sets(wc, filename, smp[i])
            end = None
            
        df = get_stats_df(sets, smp[i][0:end].capitalize(), level, label[1]) # Analyzed sets, WC!

        wc_stat.append(df) # nc_stat 

wc_all = pd.concat(wc_stat)

# %%
# wc_all.head(20)
# wc_all.tail(4)

# %%
# wc_all.loc[wc_all['Trans']=='V10']

# %%
wc_merged = pd.merge(wc_all, obs, how='outer', on='IDcal')
wc_merged.tail(2)
# Out:
#       Jdays_x  mean  high  low  max  min Trans Area Level   IDcal Type  \
# 1944      NaN   NaN   NaN  NaN  NaN  NaN   NaN  NaN   NaN  N5-286  NaN
# 1945      NaN   NaN   NaN  NaN  NaN  NaN   NaN  NaN   NaN  V5-286  NaN
#
#       Jdays_y Transect      ug.g  ug.g.SD
# 1944    286.0        N  0.045621      NaN
# 1945    286.0        V  0.026046      NaN

# %%
g = sns.FacetGrid(wc_merged, row="Area", col="Level", hue='Trans', height=6)
g.map(plt.scatter, "Jdays_x", "ug.g")
g.map(plt.errorbar, "Jdays_x", "ug.g", "ug.g.SD", marker="o", linestyle='None')
g.map(plt.plot, "Jdays_x", "mean")
g.map(plt.plot, "Jdays_x", "min")
# g.map(plt.plot, "Jdays_x", "max", color="r")

# %% [markdown]
# ## Non-constrained

# %%
# non-constrained sets
# nc_stat = []
# for level in levels:
#     if level == "Composite":
#         smp = comp
#     else:
#         smp = det
        
#     for i in range(len(smp)):
#         filename = "resM_" + smp[i] + 'CONC_real.tss'
#         sets = get_sets(nc, filename, smp[i]) # Returns sets merged
#         df = get_stats_df(sets, smp[i], level, label[0]) # Analyzed sets, NC!

#         nc_stat.append(df) # nc_stat 

# nc_all = pd.concat(nc_stat)

# %%
# nc_all.head()
nc_merged = pd.merge(nc_all, obs, how='outer', on='IDcal')
