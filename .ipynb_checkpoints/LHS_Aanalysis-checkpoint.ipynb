# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

import pickle
import os
from constants import *
from helpers import *

# %%
parameters
# Out:
# ['z3_factor',
#  'cZ0Z1',
#  'cZ',
#  'c_adr',
#  'k_g',
#  'gamma01',
#  'gammaZ',
#  'f_transp',
#  'f_oc',
#  'k_oc',
#  'beta_runoff',
#  'dt_50_aged',
#  'dt_50_ab',
#  'dt_50_ref',
#  'epsilon_iso',
#  'beta_moisture']

# %%
kge = get_dff('KGE', new=False)

# %%
kge.head()
# Out:
#           x      Param       KGE Measure Level             Set
# 0  0.933926  z3_factor  0.086945    CONC   tra  LHS_m1var1/24/
# 1  0.933926  z3_factor  0.222445    CONC   det  LHS_m1var1/24/
# 2  0.933926  z3_factor  0.074801    CONC   blk  LHS_m1var1/24/
# 3  0.933926  z3_factor  0.158282    CONC   tot  LHS_m1var1/24/
# 4  0.933926  z3_factor  0.864470    d13C   tra  LHS_m1var1/24/

# %%
x1 = kge.loc[(kge.Param == 'epsilon_iso')]
g = sns.FacetGrid(x1, col="Level", hue="Measure")
g.map(plt.scatter, "x", "KGE", alpha=.7)
g.set(xlabel='epsilon_iso')
g.add_legend()

# %%
x2 = kge.loc[(kge.Param == 'dt_50_ref')]
g = sns.FacetGrid(x2, col="Level", hue="Measure")
g.map(plt.scatter, "x", "KGE", alpha=.7)
g.set(xlabel='dt_50_ref')
g.add_legend()

# %%
nse = get_dff('NSE', new=False)

# %%
x1 = nse.loc[(nse.Param == 'epsilon_iso')]
g = sns.FacetGrid(x1, col="Level", hue="Measure")
g.map(plt.scatter, "x", "NSE", alpha=.7)
g.set(xlabel='epsilon_iso')
g.add_legend()

# %%
x2 = nse.loc[(nse.Param == 'dt_50_ref')]
g = sns.FacetGrid(x2, col="Level", hue="Measure")
g.map(plt.scatter, "x", "NSE", alpha=.7)
g.set(xlabel='dt_50_ref')
g.add_legend()

# %% [markdown]
# ## Tests

# %%
nseEpsi = nse.loc[(nse.Param == 'epsilon_iso')]
nseDT50 = nse.loc[(nse.Param == 'dt_50_ref')]

nseDeg = pd.merge(nseEpsi, nseDT50,  how='inner', on='Set')
nseDeg = nseDeg.loc[(nseDeg.Measure_y == "d13C")]
nseDeg = nseDeg.loc[(nseDeg.NSE_y > 0.5)]
nseDeg.head()
# nseBeh = nse.loc[(nse.NSE > -.5)]
# nseBeh
